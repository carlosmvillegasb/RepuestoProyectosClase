# %% [markdown]
# [Nick Maclaren](http://people.ds.cam.ac.uk/nmm1/) --Notas de Fortran, C++, cómputo en paralelo, cómo escribir buenos programas, etc

# %% [markdown]
# [Randall LeVeque](https://www.coursera.org/course/scicomp) --Curso de cómputo científico de alto rendimiento

# %% [markdown]
# ### Las notas de estabilidad y simplecticidad las subiré pronto.

# %% [markdown]
# ### Animaciones en Julia

# %%
using PyCall
using PyPlot

@pyimport matplotlib.animation as anim
# Out:
# INFO: Loading help data...

# %%
# Configuración del lienzo
fig = figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
global line = ax[:plot]([], [], lw=2)[1]

# Inicialización
function init()
    global line
    line[:set_data]([], [])
    return (line,None)
end

# Esta función dibuja lo que aparece en cada cuadro de la animación
# i es el número de cuadro o el n-ésimo paso de tiempo
# Por ejemplo, puede ser el número de paso en el método de Euler
# La función es llamada secuencialmente por anim.FuncAnimation para cada cuadro
function animate(i)
    x = linspace(0, 2, 1000)
    y = sin(2 * pi * (x - 0.02 * i))
    global line
    line[:set_data](x, y)
    return (line,None)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f23709023d0>)
# animate (generic function with 1 method)

# %%
# Generamos la animación.  blit=True significa que sólo redibuja lo que cambió de un cuadro a otro
myanim = anim.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=true);

# Guardamos la animación en un archivo .mp4. Listo para subir a YouTube
myanim[:save]("sinplot.mp4", extra_args=["-vcodec", "libx264"])

# Mostramos la animación aquí en el cuadernobb
display("text/html", string("""<video autoplay controls><source src="data:video/mp4;base64,""",
                            base64(open(readbytes,"sinplot.mp4")),"""" type="video/mp4"></video>"""))
# Out:
# <video autoplay controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# Para que se vea el video, en Ubuntu puede ser necesario instalar `ubuntu-restricted-extras` y en Firefox configurar `media.gstreamer.enabled` como **true** en about:config.

# %% [markdown]
# También podemos guardar la animación en formato GIF e incluirla fácilmente usando Markdown.

# %%
myanim = anim.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=true);
myanim[:save]("sinplot.gif", writer="imagemagick", fps=10);

# %% [markdown]
# `![anim](sinplot.gif)`
# ![anim](sinplot.gif)

# %% [markdown]
# Las animaciones sirven para ver cómo cambian cosas que no podemos ver en un experimento. Por ejemplo, la energía del sistema o el espacio fase.

# %% [markdown]
# ### Trompo de Kovalevskaya

# %% [markdown]
# No puedo poner el video por cuestiones de derechos de autor.
#
# Puntos importantes:
#
# - Los trompos integrables son: el de Euler, el de Lagrange y el de Kovalevskaya
# - El espacio fase de un sistema integrable está estructurado en toros
# - En el espacio fase hay regiones muy pequeñas, que corresponden a comportamientos cualitativamente distintos a las regiones vecinas
# - Los gráficos 3D del video fueron hechos con [POV-Ray](http://www.povray.org/)

# %% [markdown]
# ### Péndulo invertido

# %% [markdown]
# Un péndulo simple invertido, cuyo soporte oscila verticalmente con la frecuencia y la amplitud adecuadas, puede ser estable. En otras palabras, es otra manera de que una escoba apoyada verticalmente sobre la palma de tu mano no se caiga. Tiene aplicaciones en teoría del control y en robótica. Es un tema interesante para proyecto del curso. Más información en el libro de [Corben y Stehle](http://books.google.com.mx/books?id=baijAQAAQBAJ)

# %% [markdown]
# ### Levitron

# %% [markdown]
# [Video](https://www.youtube.com/watch?v=GMVtlNbMwHw) en YouTube
#
# [Explicación](http://michaelberryphysics.files.wordpress.com/2013/07/berry271.pdf) de Michael Berry. Ganó el IgNobel por hacer levitar una rana.
#
# [Explicación](http://www.hep.princeton.edu/~mcdonald/examples/levitron.ps) de Kirk McDonald. En su página hay cientos de ejemplos de fenómenos físicos. Son fascinantes.
#
# La estabilidad depende de la temperatura, la intensidad del campo magnético, la frecuencia de rotación del trompo y la altura del trompo respecto a la base.
